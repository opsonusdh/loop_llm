# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %run "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/scripts/visualize_model.py"--checkpoint "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/latest.pt" --data "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/train.bin" --data-dtype uint16 --prompt "def fibonacci(n):" --seed 42 --inline
# Out:
# [viz] device: cpu
# [viz] checkpoint: C:\Users\Admin\codes\loop_llm v2\loop_transformer_pkg\latest.pt
# [viz] diagnostic batch: random corpus batch (seed=42, starts=[21455603, 3735650])
# [viz] shape: (2, 320) | token range: [11, 48736]
# [viz] selected layer: 5/5
# [viz] loop losses: [5.77455, 5.77132, 5.77029, 5.77012]
# [viz] mean exit lambdas: [0.24219, 0.32752, 0.44663, 0.48045]
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\checkpoint.py:1399: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with device_autocast_ctx, torch.cpu.amp.autocast(**cpu_autocast_kwargs), recompute_context:  # type: ignore[attr-defined]
# [viz] fresh diagnostic loss: 5.72493
# [viz] fresh diagnostic total grad norm: 2.30542
# [viz] inline mode: displaying figures, nothing written to disk
# ...
