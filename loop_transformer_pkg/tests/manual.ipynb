# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %run "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/scripts/visualize_model.py"--checkpoint "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/latest.pt" --data "C:/Users/Admin/codes/loop_llm v2/loop_transformer_pkg/train.bin" --data-dtype uint16 --prompt "The future of artificial intelligence is"  --seed 0  --inline
# Out:
# [viz] device: cpu
# [viz] checkpoint: C:\Users\Admin\codes\loop_llm v2\loop_transformer_pkg\latest.pt
# [viz] diagnostic batch: random corpus batch (seed=0, starts=[12926687, 14112040])
# [viz] shape: (2, 320) | token range: [0, 50271]
# [viz] selected layer: 3/5
# [viz] loop losses: [4.29445, 4.29487, 4.29557, 4.29627]
# [viz] mean exit lambdas: [0.26648, 0.36502, 0.51534, 0.55325]
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\checkpoint.py:1399: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with device_autocast_ctx, torch.cpu.amp.autocast(**cpu_autocast_kwargs), recompute_context:  # type: ignore[attr-defined]
# [viz] fresh diagnostic loss: 4.25159
# [viz] fresh diagnostic total grad norm: 1.77698
# [viz] inline mode: displaying figures, nothing written to disk
# ...
